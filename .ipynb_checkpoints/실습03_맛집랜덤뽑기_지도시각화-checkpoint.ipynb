# %% [markdown]
# ## 실습02번에서 랜덤하게 뽑은 맛집을 지도에 시각화해봅시다

# %% [markdown]
# #### 지도에 시각화하려면 어떤 정보가 필요할까요?
#
# 저희가 평소 이용하는 네이버 지도, 구글맵 등은 지역포인트를 위/경도로 표시합니다.
#
# 저희도 이처럼 데이터를 위/경도로 변환하는 여러 방법을 알아보도록 합시다.

# %%
import sys
import time
from selenium import webdriver
from selenium.common import exceptions

# %% [markdown]
# # 데이터 수집을 위한 망고플레이트 크롤링

# %% [markdown]
# #### 브라우저 객체 생성

# %%
driver = webdriver.Chrome()
driver.get("https://www.mangoplate.com/")

# %% [markdown]
# #### 망고플레이트 검색창 엘리먼트 탐색 및 검색어 입력

# %%
search_element = driver.find_element_by_css_selector('#main-search')
search_element.clear()
search_element.send_keys('한대앞역')

search_button = driver.find_element_by_css_selector(".btn-search")
search_button.click()

# %% [markdown]
# # 식당 상호명 리스트 생성

# %%
restaurant_list = driver.find_element_by_css_selector('ul.list-restaurants')
restaurant_info = restaurant_list.find_elements_by_css_selector('figure.restaurant-item')

total_restaurant_info_list = []
for i in restaurant_info[:10]:
    try:
        name, address = i.find_element_by_css_selector('.thumb img').get_attribute('alt').split('사진 -')
        total_restaurant_info_list.append((name.strip(), address.strip()))
    except(exceptions.NoSuchElementException):
        break

# 오류수정 17.10.10
# 한대앞역 으로 검색했을때는 여러 페이지 등장 했으나, 다른 검색어 '안산 한양대' 의 경우에는
#  1페이지 밖에 없어서 .paging 엘리먼트들이 없어서 ElementNotVisibleException 발생.
# 만약, 이 오류라면 pass 하는 것으로 로직변경
try:
    page_nums = driver.find_element_by_css_selector('.paging').find_elements_by_css_selector('.ng-binding.ng-scope')[1:]

    cnt = 0
    for p in page_nums:
        cnt += 1
        sys.stdout.write('\r%d / %d' % (cnt, len(page_nums)))
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        p.click()
        time.sleep(5)
        restaurant_list = driver.find_element_by_css_selector('ul.list-restaurants')
        restaurant_info = restaurant_list.find_elements_by_css_selector('figure.restaurant-item')
        for i in restaurant_info[:10]:
            name, address = i.find_element_by_css_selector('.thumb img').get_attribute('alt').split('사진 -')
            total_restaurant_info_list.append((name.strip(), address.strip()))
except(exceptions.ElementNotVisibleException) as e:
    pass

print('END!')
# Out:
# 9 / 9END!

# %% [markdown]
# #### 한대앞역 망고플레이트 맛집 상호명과 주소

# %%
total_restaurant_info_list[:3]
# Out:
# [('불로불러참숯바베큐치킨', '경기도 안산시 상록구 이동 720'),
#  ('마당닭칼국수', '경기도 안산시 상록구 사동 1559-3'),
#  ('황토우렁마을쌈밥', '경기도 안산시 상록구 사동 1558-3')]

# %% [markdown]
# #### Pandas 로 csv파일로 만듭시다

# %%
import pandas as pd

# %%
restaurant_df = pd.DataFrame(total_restaurant_info_list, columns=['name', 'address'])

# %%
restaurant_df.to_csv('./한대앞_망고플레이트_맛집목록.csv', index=False, encoding='utf8')

# %%
restaurant_df
# Out:
#            name                 address
# 0   불로불러참숯바베큐치킨      경기도 안산시 상록구 이동 720
# 1        마당닭칼국수   경기도 안산시 상록구 사동 1559-3
# 2      황토우렁마을쌈밥   경기도 안산시 상록구 사동 1558-3
# 3         두드림치킨   경기도 안산시 상록구 사동 1569-1
# 4           양푼이   경기도 안산시 상록구 이동 715-10
# 5           메밀촌    경기도 안산시 상록구 이동 659-1
# 6          보쌈마루   경기도 안산시 상록구 사동 1209-1
# 7       올리브샌드위치   경기도 안산시 상록구 사동 1581-1
# 8         김민준피자   경기도 안산시 상록구 사동 1266-2
# 9          금산식당   경기도 안산시 상록구 사동 1525-9
# 10         카페그레   경기도 안산시 상록구 사동 1171-2
# 11           마루   경기도 안산시 상록구 사동 1149-6
# 12        고기와득이   경기도 안산시 상록구 사동 1518-2
# 13       투썸플레이스   경기도 안산시 상록구 이동 716-11
# 14           취해   경기도 안산시 상록구 사동 1569-6
# 15        키친모리아  경기도 안산시 상록구 사동 1568-11
# 16           네모     경기도 안산시 상록구 사동 1209
# 17      한양통닭한마리   경기도 안산시 상록구 사동 1169-2
# 18         폼프리츠   경기도 안산시 상록구 사동 1149-5
# 19         보약족발    경기도 안산시 상록구 이동 715-3
# 20       이바돔감자탕    경기도 안산시 상록구 이동 720-2
# 21    느티나무집생태찌개   경기도 안산시 상록구 사동 1203-2
# 22          미술관    경기도 안산시 상록구 이동 715-1
# 23  승혜네김치전골두루치기   경기도 안산시 상록구 사동 1275-1
# 24           소락     경기도 안산시 상록구 사동 1519
# 25         소래포구   경기도 안산시 상록구 이동 716-11
# 26         파실리따   경기도 안산시 상록구 사동 1544-4
# 27         명장한우    경기도 안산시 상록구 이동 720-2
# 28       연안생태찌개  경기도 안산시 상록구 사동 1208-10
# 29        스낵플랜트   경기도 안산시 상록구 사동 1570-7
# ..          ...                     ...
# 70           황산      경기도 안산시 상록구 이동 715
# 71      장모님옻닭보쌈     경기도 안산시 상록구 사동 1277
# 72           우당    경기도 안산시 상록구 이동 716-3
# 73     예산닭갈비감자탕   경기도 안산시 상록구 사동 1571-1
# 74         부즈위드    경기도 안산시 상록구 이동 632-6
# 75     코리아숯불바베큐    경기도 안산시 상록구 이동 538-8
# 76        안산불고기   경기도 안산시 상록구 사동 1267-5
# 77        연평도게장    경기도 안산시 상록구 이동 663-3
# 78     공주네회조개구이     경기도 안산시 상록구 사동 1518
# 79      굴다리잔치국수   경기도 안산시 상록구 이동 539-14
# 80         파파호두    경기도 안산시 상록구 이동 716-3
# 81        청학골오리  경기도 안산시 상록구 사동 1172-14
# 82     24시수타신짬뽕    경기도 안산시 상록구 이동 691-9
# 83         펀비어킹    경기도 안산시 상록구 이동 715-3
# 84          삼사오   경기도 안산시 상록구 이동 710-15
# 85       명옥부대찌개  경기도 안산시 상록구 사동 1519-15
# 86           료엔    경기도 안산시 상록구 이동 715-8
# 87          피자헐   경기도 안산시 상록구 사동 1286-8
# 88      박혜자낙지마당  경기도 안산시 상록구 사동 1185-15
# 89     주미랑도토리마당    경기도 안산시 상록구 이동 657-4
# 90  불로불러참숯바베큐치킨      경기도 안산시 상록구 이동 720
# 91       마당닭칼국수   경기도 안산시 상록구 사동 1559-3
# 92     황토우렁마을쌈밥   경기도 안산시 상록구 사동 1558-3
# 93        두드림치킨   경기도 안산시 상록구 사동 1569-1
# 94          양푼이   경기도 안산시 상록구 이동 715-10
# 95          메밀촌    경기도 안산시 상록구 이동 659-1
# 96         보쌈마루   경기도 안산시 상록구 사동 1209-1
# 97      올리브샌드위치   경기도 안산시 상록구 사동 1581-1
# 98        김민준피자   경기도 안산시 상록구 사동 1266-2
# 99         금산식당   경기도 안산시 상록구 사동 1525-9
#
# [100 rows x 2 columns]

# %% [markdown]
# #### 1. Geocode by Awesome Table 사용
#
# 특강 시, 진행예정

# %%
# 특강에서 설명할 적용방법을 진행 후, 아래의 코드 주석을 해제해주세요.

restaurant_df = pd.read_csv('./restraunt_list.csv')
restaurant_df.head(5)
restaurant_df.columns = ['name', 'address', 'latitude', 'longitude']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-5324287a980f> in <module>()
#       1 # 특강에서 설명할 적용방법을 진행 후, 아래의 코드 주석을 해제해주세요.
#       2
# ----> 3 restaurant_df = pd.read_csv('./restraunt_list.csv')
#       4 restaurant_df.head(5)
#       5 restaurant_df.columns = ['name', 'address', 'latitude', 'longitude']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     760             self.options['has_index_names'] = kwds['has_index_names']
#     761
# --> 762         self._make_engine(self.engine)
#     763
#     764     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#     964     def _make_engine(self, engine='c'):
#     965         if engine == 'c':
# --> 966             self._engine = CParserWrapper(self.f, **self.options)
#     967         else:
#     968             if engine == 'python':
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1580         kwds['allow_leading_cols'] = self.index_col is not False
#    1581
# -> 1582         self._reader = parsers.TextReader(src, **kwds)
#    1583
#    1584         # XXX
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas\_libs\parsers.c:4209)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas\_libs\parsers.c:8873)()
#
# FileNotFoundError: File b'./restraunt_list.csv' does not exist

# %% [markdown]
# #### 2. google geocode API를 사용

# %%
import requests
import json

def get_latitude_longitude(addr):
    '''
    DESCRIPTION: 주소를 입력하면 위도(latitude)/경도(longitude)를 반환하는 함수 
    ex) get_latitude_longitude('경기도 안산시 상록구 한양대학로 55')
    '''
    location = addr
    response = requests.get('http://maps.googleapis.com/maps/api/geocode/json?sensor=false&language=ko&address=' + location)    
    loc_dict = json.loads(response.text)
    latitude = loc_dict['results'][0]['geometry']['location']['lat'] 
    longitude = loc_dict['results'][0]['geometry']['location']['lng']
    return [latitude, longitude]

# %%
import pandas as pd
import os
restraurant_df = pd.read_csv('./한대앞_망고플레이트_맛집목록_위경도.csv', engine="python")

# %%
latitude_list = []
longitude_list = []
for i in restaurant_df['address'].values:
    lat, lon = get_latitude_longitude(i)
    latitude_list.append(lat)
    longitude_list.append(lon)

restaurant_df['latitude'] = latitude_list
restaurant_df['longitude'] = longitude_list

# 수정 17.10.10 - API이용 버전 위/경도 반영 DataFrame 저장
restaurant_df.to_csv('./hj_한대앞_망고플레이트_맛집목록_위경도.csv', index=False, encoding='utf8')

# %%
restaurant_df.head(20)

# %%
import folium

# 오류수정 17.10.10 - Latitude, Longitude를 latitude, longitude로 변경. 
hanyang_univ_map = folium.Map(location=[  37.298524, 126.834712], zoom_start=15)
for l in restaurant_df[['name', 'latitude', 'longitude']].values:
#    folium.Marker(l[1:],popup=l[0], icon=folium.Icon(color='red')).add_to(한양대지도)
    folium.CircleMarker(l[1:], popup=l[0], color='red', fill_color='red', radius=5).add_to(hanyang_univ_map)

# %%
hanyang_univ_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 식당 랜덤하게 뽑기

# %%
import random
# 식당 랜덤뽑기
rand_restaurant = random.choice(total_restaurant_info_list)[0]
# 식당정보 데이터프레임에서 뽑은 식당 정보 추출
print(restaurant_df[restaurant_df['name'] == rand_restaurant])
rand_latlng = restaurant_df[restaurant_df['name'] == rand_restaurant][['latitude', 'longitude']].values[0]
print(rand_latlng)
# Out:
#         name                address   latitude   longitude
# 47  회식의달인생고기  경기도 안산시 상록구 이동 716-11  37.308122  126.852035
# [  37.308122   126.8520347]

# %%
# 지도 
# 오류 수정 17.10.10 - 지도 마커가 색칠되지않아 color를 red로 변경

hanyang_univ_map = folium.Map(location=[  37.300853, 126.842930], zoom_start=15)
folium.CircleMarker(rand_latlng, color='red', fill_color='red', radius=5).add_to(hanyang_univ_map)
hanyang_univ_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
